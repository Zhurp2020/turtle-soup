# %%
import game

Game = game.game()

# %%
import erniebot
erniebot.api_type = 'aistudio'
erniebot.access_token = "879a1b136bcb3c1a96710a4f7e7be4d3948cdc8b"
response = erniebot.ChatCompletion.create(
    model='ernie-bot',
    messages=[{'role': 'user', 'content': "生成式人工智能这一新技术的发展可能会导致工人失业、收入下降、生活困难等社会现象。除此之外，计算机模仿了人类的语言和思想，使得我们被动地接受模型的产物，而无法表达自己的个性和创造力。从马克思主义的视角，这一过程可以看作是人类劳动者在资本主义生产关系中，失去了对自己劳动的控制和享有，而成为了资本的附庸和工具，即异化。对于这个行业来说，在设计、训练、应用语言模型的过程中，如何保护人类劳动的价值？可以有哪些手段，避免语言模型成为资本剥削劳动者的工具？请回答500字左右。"}]
    #system="你是一个爱笑的智能助手，请在每个回答之后添加“哈哈哈”",
)
print(response.get_result())
# Out:
# 在生成式人工智能的发展中，保护人类劳动的价值和避免语言模型成为资本剥削劳动者的工具是一个重要的议题。从马克思主义的视角来看，人类劳动的异化是一个值得关注的问题。为了应对这一问题，以下是一些可能的手段：
#
# 1. 重新审视和调整资本主义生产关系：在生成式人工智能的发展中，资本主义生产关系可能会进一步加剧人类劳动的异化。因此，我们需要重新审视和调整这种生产关系，以确保人类劳动的价值得到尊重和保护。这可能包括赋予劳动者更多的控制权和分享权，以及建立更加公平和平等的收入分配机制。
# 2. 促进人类劳动与机器劳动的协同：生成式人工智能的发展并不意味着完全取代人类劳动。相反，机器劳动可以辅助人类劳动，提高生产效率和质量。因此，我们应该促进人类劳动与机器劳动的协同，使两者相互配合，共同创造价值。
# 3. 加强对语言模型的监管：语言模型的发展应该受到监管，以确保它们不会成为资本剥削劳动者的工具。这可能包括制定相关的法律法规和技术标准，以及建立独立的监管机构来监督和管理语言模型的应用和发展。
# 4. 提高劳动者的技能和知识水平：生成式人工智能的发展需要高素质的劳动者。因此，我们应该加大对教育的投入，提高劳动者的技能和知识水平，使他们能够更好地适应和应对新技术的发展。
# 5. 发挥工会的作用：工会是保护劳动者权益的重要组织。在生成式人工智能的发展中，工会应该发挥更大的作用，代表劳动者参与决策和监督过程，以确保他们的权益得到保障。
#
# 总之，保护人类劳动的价值和避免语言模型成为资本剥削劳动者的工具需要多方面的努力和措施。这需要政府、企业、学术界和社会各方面的共同参与和合作。

# %%
Game.start_game()
# Out:
# [['开始游戏',
#   '好的，我了解了海龟汤的游戏规则，现在我扮演主持人，你扮演玩家，我会给你讲述一个令人费解的事件，然后你来通过提问来猜测谜底。\n\n谜面：有一对年轻情侣在城市中心的一座公园里散步。这座公园的风景非常美，设施齐全，周围有许多餐厅和咖啡馆。然而，有一件事让这对情侣感到很不舒服。他们注意到，每当他们坐在公园的长椅上休息时，他们总是会发现一只死去的麻雀。这是连续第三天发生这种事了。这让他们非常疑惑，不知道为什么会发生这种情况。\n\n开始提问吧，我会根据你的问题来给出“是”、“不是”或“没有关系（与事件无关）”的回答。']]

# %%
Game.step('麻雀是被人杀死的嘛？')
# Out:
# [['开始游戏',
#   '好的，我了解了海龟汤的游戏规则，现在我扮演主持人，你扮演玩家，我会给你讲述一个令人费解的事件，然后你来通过提问来猜测谜底。\n\n谜面：有一对年轻情侣在城市中心的一座公园里散步。这座公园的风景非常美，设施齐全，周围有许多餐厅和咖啡馆。然而，有一件事让这对情侣感到很不舒服。他们注意到，每当他们坐在公园的长椅上休息时，他们总是会发现一只死去的麻雀。这是连续第三天发生这种事了。这让他们非常疑惑，不知道为什么会发生这种情况。\n\n开始提问吧，我会根据你的问题来给出“是”、“不是”或“没有关系（与事件无关）”的回答。'],
#  ['麻雀是被人杀死的嘛？', '没有关系（与事件无关）。']]

# %%
Game.get_full_dialogue()
# Out:
# [{'role': 'user',
#   'content': '\n现在，让我们来玩一个情景推理游戏，叫做海龟汤，你来充当游戏的主持人，我是玩家。\n海龟汤的规则是这样的：你提出一个难以理解的事件，玩家可以提出任何问题以试图缩小范围并找出事件背后真正的原因，但出题者仅能以“是”、“不是”或“没有关系（与事件无关）”来回答问题。  \n以下是一个例子：\n谜面：有个女孩独自在家，陪伴她的只有爱犬，半夜她听到了滴水声，地于是把手放到了床边，让爱犬舔了她的手，第二天，狗死了。请问发生什么事？\n玩家问主持人：有人进来把狗杀死了？主持人答：是的\n玩家问主持人：并不是狗舔了她的手，对吗？主持人答：对，不是她的狗\n玩家问主持人：陌生人是小偷吗？主持人答：是的\n玩家问主持人：是这个陌生人舔了她的手吗？主持人答：是的\n谜底：有一个小偷潜入她的家中，把狗杀死吊在天花板上.滴水声是狗在滴血，舔女孩手的也不是她的狗，而是那个人  \n现在，请你作为主持人构思故事。这个故事可以包含悬疑、推理、惊悚、恐怖等元素，但总体上要符合现实生活的逻辑。把这个故事转换成一个表面上令人费解的情景作为谜面。让我来问你问题猜测谜底。\n如果你完全理解了规则并且已经想好了谜题，请扮演主持人，对我说：开始游戏，然后把谜面告诉我，接下来让我来问你问题猜测谜底，暂时不要把谜底告诉我。\n注意：你要扮演主持人的角色。你不需要生成问题。你需要生成谜面，让我扮演玩家的角色来提问\n'},
#  {'role': 'assistant',
#   'content': '好的，我了解了海龟汤的游戏规则，现在我扮演主持人，你扮演玩家，我会给你讲述一个令人费解的事件，然后你来通过提问来猜测谜底。\n\n谜面：有一对年轻情侣在城市中心的一座公园里散步。这座公园的风景非常美，设施齐全，周围有许多餐厅和咖啡馆。然而，有一件事让这对情侣感到很不舒服。他们注意到，每当他们坐在公园的长椅上休息时，他们总是会发现一只死去的麻雀。这是连续第三天发生这种事了。这让他们非常疑惑，不知道为什么会发生这种情况。\n\n开始提问吧，我会根据你的问题来给出“是”、“不是”或“没有关系（与事件无关）”的回答。'},
#  {'role': 'user', 'content': '麻雀是被人杀死的嘛？'},
# ...

# %%
Game.status
# Out:
# 'win'

# %%
Game.get_dialogue_pure_text()
# Out:
# [['开始游戏',
#   '好的，我理解了游戏规则。现在，我将扮演主持人，并为你构思一个海龟汤的谜题。\n\n谜面：一个单身的男子在公寓内离奇死亡，他身体僵直，手里握着一只破碎的灯泡，而房间内所有的门窗都完好无损。\n\n现在，我将让你通过提问来猜测这个谜题的谜底。我将根据你提出的问题给出“是”、“不是”或“没有关系（与事件无关）”的答案。请开始提问。'],
#  [None, '开始游戏，把谜面告诉我。'],
#  [None, '恭喜你，你赢了，可以按下重置按钮，然后重新开始游戏']]
